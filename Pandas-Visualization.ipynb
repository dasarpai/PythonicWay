# %% [markdown]
# #### Pandas Visualization

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
s1 = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000',periods=1000)).cumsum()

# %%
s1.head(3)
# Out:
# 2000-01-01   -1.917543
# 2000-01-02   -3.046532
# 2000-01-03   -2.333310
# Freq: D, dtype: float64

# %%
plt.figure()
s1.plot()
plt.show()

# %%
## Random date generation???

# %%
df2=pd.DataFrame(np.random.randn(1000,4), index=s1.index, columns=list('ABCD')).cumsum()

# %%
df2.head(3)
# Out:
#                    A         B         C         D
# 2000-01-01 -0.372058  0.073920  0.063974 -0.285996
# 2000-01-02 -1.040737 -0.919196 -1.506960 -1.393282
# 2000-01-03 -1.907127 -1.581505 -1.838430 -1.453370

# %%
plt.figure()
df2.plot()
plt.show()

# %%
df3= pd.DataFrame(np.random.randn(1000,2), columns=['b','c']).cumsum()
df3['a']=pd.Series(list (range(len(df1))))
df3.plot(x="a",y="b")
plt.show()

# %%
df2.iloc[5].plot(kind="bar")
plt.show()

# %%
plt.figure()
df2.iloc[5].plot.bar()
plt.axhline(0, color="k")
plt.show()

# %%
df4= pd.DataFrame(np.random.rand(4,2),columns=["p","q"])
df4
# Out:
#           p         q
# 0  0.220622  0.464465
# 1  0.437208  0.766829
# 2  0.821214  0.081559
# 3  0.557182  0.437189

# %%
df4= pd.DataFrame(np.random.rand(4,2),columns=["p","q"]).cumsum()
df4
# Out:
#           p         q
# 0  0.351148  0.492056
# 1  1.174608  0.546959
# 2  2.018497  0.565922
# 3  2.841397  1.369541

# %%
df4 = pd.DataFrame(np.random.rand(10,4), columns=['a','b','c','d'])
plt.figure()
df4.plot.bar()
plt.show()

# %%
df4.plot.bar(stacked=True)

# %%
df4.plot.barh()

# %%
df4.plot.barh(stacked=True)
plt.show()

# %%
df5= pd.DataFrame( {"a": np.random.randn(1000)+1, "b":np.random.randn(1000), 
                    "c":np.random.randn(1000)-1}, columns=['a','b','c'])
plt.figure()
df5.plot.hist(alpha=.5)
plt.show()

# %%
df5= pd.DataFrame( {"a": np.random.randn(1000)+1, "b":np.random.randn(1000), 
                    "c":np.random.randn(1000)-1}, columns=['a','b','c'])
plt.figure()
df5.plot.hist(stacked=True, bins=20, alpha=.7)
plt.show()

# %%
df5= pd.DataFrame( {"a": np.random.randn(1000)+1, "b":np.random.randn(1000), 
                    "c":np.random.randn(1000)-1}, columns=['a','b','c'])
plt.figure()
df5.plot.hist(stacked=True, orientation="horizontal", bins=20, alpha=.7)
plt.show()

# %%
df5= pd.DataFrame(np.random.randn(1000,4), index=s1.index, columns=list("ABCD")).cumsum()
plt.figure()
df5["A"].diff().hist()

# %%
plt.figure()
df5.diff().hist(color="k", alpha=.5, bins=50)
plt.show()

# %%
df5.diff(periods=-1,axis=0).tail(5)
# Out:
#                    A         B         C         D
# 2002-09-22 -1.134791  0.832551 -0.581071  0.349550
# 2002-09-23  1.044705 -2.543715  1.085169 -1.381548
# 2002-09-24  0.607638 -0.321804 -2.307502 -0.284951
# 2002-09-25 -0.167485  0.038151  0.253478  0.069661
# 2002-09-26       NaN       NaN       NaN       NaN

# %%
df5.head(5)
# Out:
#                    A         B         C         D
# 2000-01-01 -1.482984  0.508115 -0.579101  0.362948
# 2000-01-02 -1.877352 -0.185504 -1.515517  0.193055
# 2000-01-03 -4.479822 -1.491626 -1.755253  0.105580
# 2000-01-04 -4.210806  0.552829 -0.743746  1.199031
# 2000-01-05 -4.382151  0.853657  0.579175 -0.308235

# %%
data= pd.Series(np.random.randn(1000))
plt.figure()
data.hist(by =np.random.randint(0,3,1000), figsize=(6,4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FA0FDF4DA0>,
# ...
#       dtype=object)

# %%
df6= pd.DataFrame(np.random.randn(10,5), columns=['A','B','C','D','E'])
plt.figure()
df6.plot.box()
plt.show()

# %%
color = dict( boxes="DarkGreen", whiskers="DarkOrange", medians="DarkBlue", caps="Gray")

# %%
plt.figure()
df6.plot.box(color=color, sym="r+")

# %% [markdown]
# Parameters
#  |      ----------
#  |      data : DataFrame
#  |      x : label or position, default None
#  |      y : label, position or list of label, positions, default None
#  |          Allows plotting of one column versus another
#  |      kind : str
#  |          - 'line' : line plot (default)
#  |          - 'bar' : vertical bar plot
#  |          - 'barh' : horizontal bar plot
#  |          - 'hist' : histogram
#  |          - 'box' : boxplot
#  |          - 'kde' : Kernel Density Estimation plot
#  |          - 'density' : same as 'kde'
#  |          - 'area' : area plot
#  |          - 'pie' : pie plot
#  |          - 'scatter' : scatter plot
#  |          - 'hexbin' : hexbin plot
#  |      ax : matplotlib axes object, default None
#  |      subplots : boolean, default False
#  |          Make separate subplots for each column
#  |      sharex : boolean, default True if ax is None else False
#  |          In case subplots=True, share x axis and set some x axis labels to
#  |          invisible; defaults to True if ax is None otherwise False if an ax
#  |          is passed in; Be aware, that passing in both an ax and sharex=True
#  |          will alter all x axis labels for all axis in a figure!
#  |      sharey : boolean, default False
#  |          In case subplots=True, share y axis and set some y axis labels to
#  |          invisible
#  |      layout : tuple (optional)
#  |          (rows, columns) for the layout of subplots
#  |      figsize : a tuple (width, height) in inches
#  |      use_index : boolean, default True
#  |          Use index as ticks for x axis
#  |      title : string or list
#  |          Title to use for the plot. If a string is passed, print the string at
#  |          the top of the figure. If a list is passed and `subplots` is True,
#  |          print each item in the list above the corresponding subplot.
#  |      grid : boolean, default None (matlab style default)
#  |          Axis grid lines
#  |      legend : False/True/'reverse'
#  |          Place legend on axis subplots
#  |      style : list or dict
#  |          matplotlib line style per column
#  |      logx : boolean, default False
#  |          Use log scaling on x axis
#  |      logy : boolean, default False
#  |          Use log scaling on y axis
#  |      loglog : boolean, default False
#  |          Use log scaling on both x and y axes
#  |      xticks : sequence
#  |          Values to use for the xticks
#  |      yticks : sequence
#  |          Values to use for the yticks
#  |      xlim : 2-tuple/list
#  |      ylim : 2-tuple/list
#  |      rot : int, default None
#  |          Rotation for ticks (xticks for vertical, yticks for horizontal plots)
#  |      fontsize : int, default None
#  |          Font size for xticks and yticks
#  |      colormap : str or matplotlib colormap object, default None
#  |          Colormap to select colors from. If string, load colormap with that name
#  |          from matplotlib.
#  |      colorbar : boolean, optional
#  |          If True, plot colorbar (only relevant for 'scatter' and 'hexbin' plots)
#  |      position : float
#  |          Specify relative alignments for bar plot layout.
#  |          From 0 (left/bottom-end) to 1 (right/top-end). Default is 0.5 (center)
#  |      table : boolean, Series or DataFrame, default False
#  |          If True, draw a table using the data in the DataFrame and the data will
#  |          be transposed to meet matplotlib's default layout.
#  |          If a Series or DataFrame is passed, use passed data to draw a table.
#  |      yerr : DataFrame, Series, array-like, dict and str
#  |          See :ref:`Plotting with Error Bars <visualization.errorbars>` for
#  |          detail.
#  |      xerr : same types as yerr.
#  |      stacked : boolean, default False in line and
#  |          bar plots, and True in area plot. If True, create stacked plot.
#  |      sort_columns : boolean, default False
#  |          Sort column names to determine plot ordering
#  |      secondary_y : boolean or sequence, default False
#  |          Whether to plot on the secondary y-axis
#  |          If a list/tuple, which columns to plot on secondary y-axis
#  |      mark_right : boolean, default True
#  |          When using a secondary_y axis, automatically mark the column
#  |          labels with "(right)" in the legend
#  |      `**kwds` : keywords
#  |          Options to pass to matplotlib plotting method

# %% [markdown]
# kind : str
#  |          - 'line' : line plot (default)
#  |          - 'bar' : vertical bar plot
#  |          - 'barh' : horizontal bar plot
#  |          - 'hist' : histogram
#  |          - 'box' : boxplot
#  |          - 'kde' : Kernel Density Estimation plot
#  |          - 'density' : same as 'kde'
#  |          - 'area' : area plot
#  |          - 'pie' : pie plot
#  |          - 'scatter' : scatter plot
#  |          - 'hexbin' : hexbin plot

# %%
plt.figure()
df6.plot.box(vert=False, positions=[1,4,5,6,9])

# %%
df6= pd.DataFrame(np.random.randn(10,5))
plt.figure()
df6.boxplot()

# %%
df7= pd.DataFrame(np.random.rand(10,2), columns=['col1','col2'])
df7['X']=pd.Series(["A","A","A","B","B","B","C","C","C","C"])
plt.figure()
df7.boxplot(by = "X")
plt.show()

# %%
df7['Y']=pd.Series(["P","P","Q","Q","R","R","Q","R","Q","P"])

# %%
plt.figure()
df7.boxplot(column=["col1","col2"], by = ["X","Y"], figsize=(10,5))
plt.show()

# %%
np.random.seed(1234)
df_box = pd.DataFrame(np.random.randn(50,2))
df_box["g"]= np.random.choice( ["Cat","Rat","Mat"], size=50)
#df_box.loc[ df_box['g']=="Rat",1] +=3
bp=df_box.boxplot(by="g")

# %%
#df_box

# %%
from pandas.plotting import scatter_matrix
df = pd.DataFrame( np.random.randn(1000,4), columns=['a','b','c','d'])
plt.figure()
scatter_matrix(df, alpha=0.2, figsize=(15,6), diagonal="kde")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FA155D89E8>,
# ...
#       dtype=object)

# %%
s1= pd.Series(np.random.randn(1000))
plt.figure()
s1.plot.kde()

# %%
from pandas.plotting import lag_plot
plt.figure()
data= pd.Series(0.1 * np.random.random(1000) +  0.9* np.sin(np.linspace(-99*np.pi, 99*np.pi, num=1000)))
lag_plot(data)

# %%
autocorrelation_plot(data)

# %%
np.linspace(1,10,50)
# Out:
# array([ 1.        ,  1.18367347,  1.36734694,  1.55102041,  1.73469388,
#         1.91836735,  2.10204082,  2.28571429,  2.46938776,  2.65306122,
#         2.83673469,  3.02040816,  3.20408163,  3.3877551 ,  3.57142857,
#         3.75510204,  3.93877551,  4.12244898,  4.30612245,  4.48979592,
#         4.67346939,  4.85714286,  5.04081633,  5.2244898 ,  5.40816327,
#         5.59183673,  5.7755102 ,  5.95918367,  6.14285714,  6.32653061,
#         6.51020408,  6.69387755,  6.87755102,  7.06122449,  7.24489796,
#         7.42857143,  7.6122449 ,  7.79591837,  7.97959184,  8.16326531,
#         8.34693878,  8.53061224,  8.71428571,  8.89795918,  9.08163265,
#         9.26530612,  9.44897959,  9.63265306,  9.81632653, 10.        ])

# %%
from pandas.plotting import autocorrelation_plot
plt.figure()
data = pd.Series(0.7* np.random.rand(1000) + 0.3*np.sin( np.linspace(-9 *np.pi, +9*np.pi, num=1000)))
autocorrelation_plot(data)

# %%
from pandas.plotting import bootstrap_plot
data = pd.Series(np.random.rand(1000))
plt.figure()
bootstrap_plot(data, size=50, samples=500, color="grey", fig=plt.figure(figsize=(15,5)))

# %%
fig, ax = plt.subplots(1,1)
df7= pd.DataFrame( np.random.rand(5,3), columns=['a','b','c'])
ax.get_xaxis().set_visible(False)
plt.figure()
df7.plot(table=True, ax=ax, figsize=(15,10))

# %%
np.random.seed(300)
df8= pd.DataFrame(np.random.rand(15,10)).applymap(abs)
#df8=df8.cumsum()
plt.figure()
df8.plot.bar(colormap="Greens", figsize=(15,5))

# %%
np.random.seed(500)
df9 = pd.DataFrame(np.random.randint(1,20,30))

# %%
df9= pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
plt.figure()
df9.plot.area()

# %%
plt.figure()
df9.plot.area(stacked=False)

# %%
df7
# Out:
#           a         b         c
# 0  0.756470  0.268764  0.396532
# 1  0.377220  0.434865  0.083448
# 2  0.343740  0.574989  0.125970
# 3  0.809975  0.938818  0.268859
# 4  0.897129  0.001439  0.611345

# %% [markdown]
# ### Scatter

# %%
df= pd.DataFrame(np.random.rand(50,4),columns=['a','b','c','d'])
plt.figure()
df.plot.scatter(x='a',y='b')

# %%
df= pd.DataFrame(np.random.rand(50,4),columns=['a','b','c','d'])
plt.figure()
ax=df.plot.scatter(x='a',y='b', color="DarkBlue", label="Group 1")
df.plot.scatter(x='c',y='d', color="DarkRed", label="Group 2", ax=ax)

# %%
df= pd.DataFrame(np.random.rand(10,6),columns=['a','b','c','d','e','f'])
plt.figure()
ax=df.plot.scatter(x='a',y='b', color="DarkBlue", label="Group 1", s=40)
ax1=df.plot.scatter(x='a',y='d', color="DarkRed", label="Group 2", ax=ax, s=60)
df.plot.scatter(x='a',y='f', color="DarkGreen", label="Group 2", ax=ax1, figsize=(15,5), s=80)

# %%
df.plot.scatter(x="a",y="b",c="r",s=50)

# %%
df.plot.scatter(x="a",y="b",c="r",s=df['c']*200)

# %%
ax=df.plot.scatter(x="a",y="b",c="c",s=50)

ax.get_xaxis().set_visible(True)
#df.plot(table=True, ax=ax, figsize=(15,10))
plt.show()

# %%
df.plot.scatter(x="a",y="b",c="r",s=df['a']*df['b']*300)

# %% [markdown]
# ### Hexgonal bin plot

# %%
df.plot.hexbin(x="a",y="b", gridsize=25)

# %%
df = pd.DataFrame( np.random.randn(1000,2), columns=['a','b'])
df['b']=df['b']+np.arange(1000)
df['z']= np.random.uniform(0,3,1000)
plt.figure()
df.plot.hexbin(x="a",y="b",C="z", reduce_C_function=np.max ,gridsize=45)

# %%
# Out:
# array([0.90756715, 1.14963062, 1.50652706, 0.1073629 , 0.13376461,
#        2.86224771, 1.80206309, 0.63914787, 2.35523276, 2.16438287])

# %%
series=pd.Series( 3*np.random.rand(4), index=["a","b","c","d"], name="series")
plt.figure()
series.plot.pie(figsize=(8,4))

# %%
df=pd.DataFrame( 3*np.random.rand(4,3), index=["a","b","c","d"], columns=['x','y','z'])
plt.figure()
df.plot.pie(subplots=True,figsize=(8,4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001FA24235F98>,
# ...
#       dtype=object)

# %%
plt.figure()
series.plot.pie( labels=['AA','BB','CC','DD'], colors=['r','g','b','c'], autopct='%0.2f', fontsize=14, figsize=(10,5))

# %%
plt.figure()
series=pd.Series( [0.1]*4, index=["a","b","c","d"], name="series2")
plt.figure()
series.plot.pie( labels=['AA','BB','CC','DD'], colors=['r','g','b','c'], autopct='%0.2f', fontsize=14, figsize=(10,5))

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects
# frequeuncy

# %%
price = pd.Series( np.random.randn(150).cumsum(), 
                  index=pd.date_range("2017-1-1",periods=150, freq='D') )

# %%
ma = price.rolling(20).mean()
mstd=price.rolling(20).std()
plt.figure()
plt.plot(price.index, price, "k")
plt.plot(price.index, ma, "b")
plt.fill_between(mstd.index, ma-2*mstd, ma+2*mstd,color="b", alpha=0.2)

# %%
ma
# Out:
# 2017-01-01         NaN
# 2017-01-02         NaN
# 2017-01-03         NaN
# 2017-01-04         NaN
# 2017-01-05         NaN
# 2017-01-06         NaN
# 2017-01-07         NaN
# 2017-01-08         NaN
# 2017-01-09         NaN
# 2017-01-10         NaN
# 2017-01-11         NaN
# 2017-01-12         NaN
# 2017-01-13         NaN
# 2017-01-14         NaN
# 2017-01-15         NaN
# 2017-01-16         NaN
# 2017-01-17         NaN
# 2017-01-18         NaN
# 2017-01-19         NaN
# 2017-01-20    0.630970
# 2017-01-21    0.670370
# 2017-01-22    0.674680
# 2017-01-23    0.607867
# 2017-01-24    0.454674
# 2017-01-25    0.264329
# 2017-01-26   -0.007391
# 2017-01-27   -0.235818
# 2017-01-28   -0.500630
# 2017-01-29   -0.762422
# 2017-01-30   -0.940622
#                 ...
# 2017-05-01   -3.277972
# 2017-05-02   -3.403704
# 2017-05-03   -3.498674
# 2017-05-04   -3.557792
# 2017-05-05   -3.583895
# 2017-05-06   -3.516267
# 2017-05-07   -3.526531
# 2017-05-08   -3.538303
# 2017-05-09   -3.524003
# ...

# %%
s=np.random.dirichlet((10, 5, 3), 20).transpose()
plt.barh(range(20), s[1])
# Out:
# <BarContainer object of 20 artists>

# %%
df = pd.DataFrame({'mass': [0.330, 4.87 , 5.97],
                   'radius': [2439.7, 6051.8, 6378.1]},
                  index=['Mercury', 'Venus', 'Earth'])
plot = df.plot.pie(y='mass', figsize=(5, 5))

# %%
import pandas as pd
from matplotlib.pyplot import pie, axis, show

df = pd.DataFrame({
    'Sex': ['male','female', 'male', 'female'],
    'Smoke': [4,1, 1, 1]})

sums = df.Smoke.groupby(df.Sex).sum()

axis('equal')

a=pie(sums, labels=sums.index)

# %%
plt.cla() #Clear an axis
plt.clf() #Clear an entire figure
plt.close() #Close a window

# %%
df[df.Smoke==1]['Sex'].value_counts().plot.pie()

# %%
plot = df.plot.pie(y='Smoke', figsize=(5, 5))

# %%
ts = pd.Series(np.random.randn(10000),
           index=pd.date_range('1/1/2000', periods=10000))

ts = ts.cumsum()
plt.gcf().autofmt_xdate()
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(10000, 4), index=ts.index, columns=list('ABCD'))
df = df.cumsum()

plt.figure();
df.plot();
