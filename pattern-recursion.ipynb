# %%
global i
i=0
l1=[]
l1m=[]
def recursion(n,N):
    l1.append ('*'*n+' '*(N-n))
    l1m.append (' '*(N-n)+'*'*n)
    if n>1:
        recursion(n-1, N)
recursion(10,10)

# %%
l2=l1.copy()
l2m=l1m.copy()
l2.sort()
l2m.sort()

# %%
#l1, l2
for i in range(n):
    print (l1[i]+l1[i])
print() 

for i in range(n):
    print (l2[i]+l2[i])
print()   

for i in range(n):
    print (l1[i]+l2[i])
print()  
    
for i in range(n):
    print (l2[i]+l1[i])
# Out:
# ********************
# ********* *********
# ********  ********
# *******   *******
# ******    ******
# *****     *****
# ****      ****
# ***       ***
# **        **
# *         *
#
# *         *
# **        **
# ***       ***
# ****      ****
# *****     *****
# ******    ******
# *******   *******
# ********  ********
# ********* *********
# ********************
#
# ***********
# ********* **
# ********  ***
# *******   ****
# ******    *****
# *****     ******
# ****      *******
# ***       ********
# **        *********
# *         **********
#
# *         **********
# **        *********
# ***       ********
# ****      *******
# *****     ******
# ******    *****
# *******   ****
# ********  ***
# ********* **
# ***********

# %%
#l1, l1m
for i in range(n):
    print (l1m[i]+l1m[i])
print() 

for i in range(n):
    print (l1[i]+l1m[i])
print()   

for i in range(n):
    print (l1m[i]+l1[i])
print()
# Out:
# ********************
#  ********* *********
#   ********  ********
#    *******   *******
#     ******    ******
#      *****     *****
#       ****      ****
#        ***       ***
#         **        **
#          *         *
#
# ********************
# *********  *********
# ********    ********
# *******      *******
# ******        ******
# *****          *****
# ****            ****
# ***              ***
# **                **
# *                  *
#
# ********************
#  ******************
#   ****************
#    **************
#     ************
#      **********
#       ********
#        ******
#         ****
#          **

# %%
#l2, l2m
for i in range(n):
    print (l2m[i]+l2m[i])
print() 

for i in range(n):
    print (l2[i]+l2m[i])
print()   

for i in range(n):
    print (l2m[i]+l2[i])
print()
# Out:
#          *         *
#         **        **
#        ***       ***
#       ****      ****
#      *****     *****
#     ******    ******
#    *******   *******
#   ********  ********
#  ********* *********
# ********************
#
# *                  *
# **                **
# ***              ***
# ****            ****
# *****          *****
# ******        ******
# *******      *******
# ********    ********
# *********  *********
# ********************
#
#          **
#         ****
#        ******
#       ********
#      **********
#     ************
#    **************
#   ****************
#  ******************
# ********************

# %%
#l1m, l2m
for i in range(n):
    print (l1m[i]+l2m[i])
print() 

for i in range(n):
    print (l2m[i]+l1m[i])
print()
# Out:
# **********         *
#  *********        **
#   ********       ***
#    *******      ****
#     ******     *****
#      *****    ******
#       ****   *******
#        ***  ********
#         ** *********
#          ***********
#
#          ***********
#         ** *********
#        ***  ********
#       ****   *******
#      *****    ******
#     ******     *****
#    *******      ****
#   ********       ***
#  *********        **
# **********         *

# %%
#l1, l2m
for i in range(n):
    print (l1[i]+l2m[i])
print() 

for i in range(n):
    print (l2m[i]+l1[i])
print()
# Out:
# **********         *
# *********         **
# ********         ***
# *******         ****
# ******         *****
# *****         ******
# ****         *******
# ***         ********
# **         *********
# *         **********
#
#          ***********
#         ***********
#        ***********
#       ***********
#      ***********
#     ***********
#    ***********
#   ***********
#  ***********
# ***********

# %%
#l1m, l2
for i in range(n):
    print (l1m[i]+l2[i])
print() 

for i in range(n):
    print (l2[i]+l1m[i])
print()
# Out:
# ***********
#  ***********
#   ***********
#    ***********
#     ***********
#      ***********
#       ***********
#        ***********
#         ***********
#          ***********
#
# *         **********
# **         *********
# ***         ********
# ****         *******
# *****         ******
# ******         *****
# *******         ****
# ********         ***
# *********         **
# **********         *

# %%
i=0
while i<n:
    print (l2m[i-1]+l2[i-1]+l2m[i]+l2[i]+l2m[i]+l2[i]+l2m[i]+l2[i])
    i+=1
# Out:
# ********************         **                  **                  **
#          **                 ****                ****                ****
#         ****               ******              ******              ******
#        ******             ********            ********            ********
#       ********           **********          **********          **********
#      **********         ************        ************        ************
#     ************       **************      **************      **************
#    **************     ****************    ****************    ****************
#   ****************   ******************  ******************  ******************
#  ****************** ************************************************************
