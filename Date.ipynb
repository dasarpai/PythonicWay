# %%
"-".join(['1','2','3'])
# Out:
# '1-2-3'

# %%
import datetime
import calendar

def add_months(d, m):
    m = d.month - 1 + m
    y = d.year + m // 12
    m = m % 12 + 1
    day = min(d.day, calendar.monthrange(y,m)[1])
    return datetime.date(y, m, day)

# %%
d1=dt.datetime(2017,5, 1, 11,54,55)

# %%
help( dt.date )

# %%
dt.timedelta(days=1)

# %%
datetime.timedelta(days=1)

# %%
from datetime import timedelta
d = timedelta(microseconds=-1)
(d.days, d.seconds, d.microseconds)

# %%
timedelta(hours=-5)
datetime.timedelta(-1, 68400)
print(_)

# %%
from datetime import timedelta
year = timedelta(days=365)
print (year)
another_year = timedelta(weeks=40, days=84, hours=23,
                          minutes=50, seconds=600)  # adds up to 365 days
print (year.total_seconds() )

year == another_year
print (year)

ten_years = 10 * year
print(ten_years)

ten_years, ten_years.days // 365
(datetime.timedelta(3650), 10)
nine_years = ten_years - year
print(nine_years)

nine_years, nine_years.days // 365
(datetime.timedelta(3285), 9)

three_years = nine_years // 3;
three_years, three_years.days // 365
print(three_years)

(datetime.timedelta(1095), 3)
abs(three_years - ten_years) == 2 * three_years + year

# %%
nine_years, nine_years.days // 365

# %%
nine_years.days/365

# %%
gmt1 = GMT1()
dt1 = datetime(2006, 11, 21, 16, 30, tzinfo=gmt1)

# %%
class GMT1(tzinfo):
    def utcoffset(self, dt):
        return timedelta(hours=1) + self.dst(dt)
    def dst(self, dt):
        # DST starts last Sunday in March
        d = datetime(dt.year, 4, 1)   # ends last Sunday in October
        self.dston = d - timedelta(days=d.weekday() + 1)
        d = datetime(dt.year, 11, 1)
        self.dstoff = d - timedelta(days=d.weekday() + 1)
        if self.dston <=  dt.replace(tzinfo=None) < self.dstoff:
            return timedelta(hours=1)
        else:
            return timedelta(0)
    def tzname(self,dt):
          return "GMT +1"

# %%
x = datetime.datetime.now()
j=[5,9,10,11,12,14,15,16,17,19,22]
i=1
while i<27:
    if i not in j:
        print(i,chr(i+64),x.strftime( "%"+chr(i+64) ), x.strftime( "%"+chr(i+96)) )
    else:
        print(i,chr(i+64), 2 )
   
    i+=1

# %%
ini_time_for_now = datetime.datetime.now()
future_date_after_2yrs = ini_time_for_now + timedelta(days = 730)
print (ini_time_for_now)
print (future_date_after_2yrs)

# %%
ini_time_for_now = datetime.datetime.now()
future_date_after_2yrs = ini_time_for_now + timedelta(days = 1)
print (ini_time_for_now)
print (future_date_after_2yrs)

# %%
ini_time_for_now = datetime.datetime.now()
future_date_after_2yrs = ini_time_for_now + timedelta(hours = 1)
print (ini_time_for_now)
print (future_date_after_2yrs)

# %%
ini_time_for_now = datetime.datetime.now()
future_date_after_2yrs = ini_time_for_now + timedelta(minutes = 1)
print (ini_time_for_now)
print (future_date_after_2yrs)

# %%
ini_time_for_now = datetime.datetime.now()
future_date_after_2yrs = ini_time_for_now + timedelta(weeks = 1)
print (ini_time_for_now)
print (future_date_after_2yrs)

# %%
ini_time_for_now = datetime.datetime.now()
future_date_after_2yrs = ini_time_for_now + timedelta(weeks = 1)
print (ini_time_for_now)
print (future_date_after_2yrs)

# %%
import calendar, datetime

def increment_month(when):
    days = calendar.monthrange(when.year, when.month)[1]
    return when + datetime.timedelta(days=days)

now = datetime.datetime.now()
print ('It is now %s' % now )
print ('In a month, it will be %s' % increment_month(now) )

# %%
x=datetime.datetime(2019, 8, 1, 14, 51, 35, 112919)

# %%
calendar.monthrange(x.year, x.month)

# %%
print (x)
y=x + datetime.timedelta(days= calendar.monthrange(x.year, x.month)[1] )
print (y)

# %%
d = datetime.date(2017,1,1)

# %%
d.strftime("%Y")

# %%
ds.strftime("%p")

# %%
calendar.monthrange(2017,2)[1]

# %%
dateStart=datetime.date(input_list[0],input_list[1],5)
print(dateStart)
add_months(dateStart,1)

# %%
import ast,sys
import datetime
import numpy as np
input_str = [2017,1,1,2017,1,1] #sys.stdin.read()
input_list = [2017,8,2,2018,1,1]
#[2017,1,1,2017,2,4]
#[2017,8,2,2018,1,1]
#[2017,1,1,2017,4,1] #ast.literal_eval(input_str)
dateStart=datetime.date(input_list[0],input_list[1],input_list[2])
dateEnd=datetime.date(input_list[3],input_list[4],input_list[5])

m_name=np.array(['January', 'February', 'March', 'April', 'May', 'June', 'July', 
        'August', 'September', 'October', 'November', 'December'])
dt=dateStart

m_list=[]
m_list.append( dt.strftime("%B") )

months=dateEnd.month-dateStart.month+1
years=(dateEnd.year-dateStart.year)
months= years*12+months

i=1
while i<months :
    dt=add_months(dateStart,i)
    m_list.append( dt.strftime("%B") )
    i=i+1


for i in m_name:
    if np.isin(i,m_list):
        print (i)

# %%
import pandas as pd
import datetime

# %%
a = datetime.datetime(2017, 6, 21, 18, 25, 30) 
b = datetime.datetime(2017, 5, 16, 8, 21, 10) 

c = a-b  
print('Difference: ', c) 
  
minutes = c.seconds / 60
print('Difference in minutes: ', minutes)
# Out:
# Difference:  36 days, 10:04:20
# Difference in minutes:  604.3333333333334

# %%
df1=pd.read_csv("dates.csv")

# %%
df1
# Out:
#      Sno                Dates
# 0      1  2016-03-14 17:32:30
# 1      2  2016-06-12 00:54:38
# 2      3  2016-01-19 12:10:48
# 3      4  2016-04-06 19:39:40
# 4      5  2016-03-26 13:38:10
# 5      6  2016-01-30 22:09:03
# 6      7  2016-06-17 22:40:40
# 7      8  2016-05-21 08:20:49
# 8      9  2016-05-27 23:16:38
# 9     10  2016-03-10 22:05:26
# 10    11  2016-05-10 22:29:55
# 11    12  2016-05-15 11:34:59
# 12    13  2016-02-19 10:11:20
# 13    14  2016-06-01 21:02:49
# 14    15  2016-05-27 01:07:10
# 15    16  2016-05-16 15:32:33
# 16    17  2016-04-11 18:08:26
# 17    18  2016-04-14 09:00:37
# 18    19  2016-06-27 10:17:10
# 19    20  2016-06-05 13:51:34
# 20    21  2016-02-28 02:31:08
# 21    22  2016-04-01 12:23:17
# 22    23  2016-04-09 03:41:30
# 23    24  2016-06-25 10:55:49
# 24    25  2016-06-03 08:56:30
# 25    26  2016-02-14 13:49:19
# 26    27  2016-02-27 22:14:51
# 27    28  2016-06-20 23:18:50
# 28    29  2016-06-13 22:12:19
# 29    30  2016-03-23 14:49:30
# ...

# %%
df = pd.DataFrame({'Date':['11/8/2011', '04/23/2008', '10/2/2019'], 
                'Event':['Music', 'Poetry', 'Theatre'], 
                'Cost':[10000, 5000, 15000]})
df
# Out:
#          Date    Event   Cost
# 0   11/8/2011    Music  10000
# 1  04/23/2008   Poetry   5000
# 2   10/2/2019  Theatre  15000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 2 columns):
# Sno      501 non-null int64
# Dates    500 non-null object
# dtypes: int64(1), object(1)
# memory usage: 7.9+ KB

# %%
#df1['Dates']= pd.to_datetime(df1['Dates'])

#df1['Dates'] = df1['Dates'].astype('datetime64[ns]')

df1['Dates'] = df1['Dates'].apply(pd.to_datetime)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 2 columns):
# Sno      501 non-null int64
# Dates    500 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 7.9 KB

# %%
from datetime import datetime

datetime_str = '09/19/18 13:55:26'

datetime_object = datetime.strptime(datetime_str, '%m/%d/%y %H:%M:%S')
datetime_object
# Out:
# datetime.datetime(2018, 9, 19, 13, 55, 26)

# %%
date_str = '09-19-2018'

date_object = datetime.strptime(date_str, '%m-%d-%Y').date()
date_object
# Out:
# datetime.date(2018, 9, 19)

# %%
date_str = '09-19-2018'

date_object = datetime.strptime(date_str, '%m-%d-%Y')
date_object
# Out:
# datetime.datetime(2018, 9, 19, 0, 0)

# %%
time_str = '13::55::26'
time_object = datetime.strptime(time_str, '%H::%M::%S').time()
time_object
# Out:
# datetime.time(13, 55, 26)

# %%
from datetime import date
today = date.today()
today
# Out:
# datetime.date(2019, 12, 9)

# %%
today.weekday()
# Out:
# 0

# %%
t = datetime.time(datetime.now())
t
# Out:
# datetime.time(14, 5, 48, 964842)

# %%
from datetime import date
from datetime import time
from datetime import datetime
from datetime import timedelta 
def main():
    ##DATETIME OBJECTS
    #Get today's date from datetime class
    today=datetime.now()
    #print (today)
    # Get the current time
    #t = datetime.time(datetime.now())
    #print "The current time is", t
    #weekday returns 0 (monday) through 6 (sunday)
    wd=date.weekday(today)
    #Days start at 0 for monday
    days= ["monday","tuesday","wednesday","thursday","friday","saturday","sunday"]
    print("Today is day number %d" % wd)
    print("which is a " + days[wd])

if __name__== "__main__":
    main()
# Out:
# Today is day number 0
# which is a monday

# %%
print ("a- ",today.strftime("%a"))
print ("A- ",today.strftime("%A"))
print ("B- ",today.strftime("%b"))
print ("B- ",today.strftime("%B"))
print ("c- ",today.strftime("%c"))
print ("C- ",today.strftime("%C"))
print ("d- ",today.strftime("%d"))
print ("D- ", today.strftime("%D") )


print ("m- ",today.strftime("%m"))
print ("x- ", today.strftime("%x"))
print ("X- ",today.strftime("%X"))
print ("y- ",today.strftime("%y"))
print ("Y- ",today.strftime("%Y"))
# Out:
# a-  Mon
# A-  Monday
# B-  Dec
# B-  December
# c-  Mon Dec  9 00:00:00 2019
# C-  20
# d-  09
# D-  12/09/19
# m-  12
# x-  12/09/19
# X-  00:00:00
# y-  19
# Y-  2019

# %%
print (timedelta(days=365, hours=8, minutes=15))
# Out:
# 365 days, 8:15:00

# %%
print ("one year from now it will be:" + str(datetime.now() + timedelta(days=365)))
# Out:
# one year from now it will be:2020-12-08 14:18:46.492245

# %%
today = date.today()  # get todays date
nyd = date(today.year, 1, 1)  # get New Year Day for the same year
nyd
# Out:
# datetime.date(2019, 1, 1)

# %%
#(df1.Dates-datetime.now())
df1.Dates = pd.to_datetime(df1.Dates)

# %%
today=datetime.now()
today
(df1.Dates-today).dt.hours
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-26b8a64d2ac5> in <module>
#       1 today=datetime.now()
#       2 today
# ----> 3 (df1.Dates-today).dt.hours
#
# AttributeError: 'TimedeltaProperties' object has no attribute 'hours'

# %%
pd.to_timedelta(df1.Dates,unit="ns")
# Out:
# 0     16874 days 17:32:30
# 1     16964 days 00:54:38
# 2     16819 days 12:10:48
# 3     16897 days 19:39:40
# 4     16886 days 13:38:10
# 5     16830 days 22:09:03
# 6     16969 days 22:40:40
# 7     16942 days 08:20:49
# 8     16948 days 23:16:38
# 9     16870 days 22:05:26
# 10    16931 days 22:29:55
# 11    16936 days 11:34:59
# 12    16850 days 10:11:20
# 13    16953 days 21:02:49
# 14    16948 days 01:07:10
# 15    16937 days 15:32:33
# 16    16902 days 18:08:26
# 17    16905 days 09:00:37
# 18    16979 days 10:17:10
# 19    16957 days 13:51:34
# 20    16859 days 02:31:08
# 21    16892 days 12:23:17
# 22    16900 days 03:41:30
# 23    16977 days 10:55:49
# 24    16955 days 08:56:30
# 25    16845 days 13:49:19
# 26    16858 days 22:14:51
# 27    16972 days 23:18:50
# 28    16965 days 22:12:19
# 29    16883 days 14:49:30
#               ...
# 471   16836 days 18:11:25
# 472   16913 days 17:29:22
# 473   16906 days 08:34:48
# 474   16908 days 01:52:55
# 475   16914 days 12:26:03
# ...

# %%
pd.to_timedelta( pd.to_datetime(df1.Dates),unit="ns", errors="ignore")
#df1.Dates
# Out:
# 0     16874 days 17:32:30
# 1     16964 days 00:54:38
# 2     16819 days 12:10:48
# 3     16897 days 19:39:40
# 4     16886 days 13:38:10
# 5     16830 days 22:09:03
# 6     16969 days 22:40:40
# 7     16942 days 08:20:49
# 8     16948 days 23:16:38
# 9     16870 days 22:05:26
# 10    16931 days 22:29:55
# 11    16936 days 11:34:59
# 12    16850 days 10:11:20
# 13    16953 days 21:02:49
# 14    16948 days 01:07:10
# 15    16937 days 15:32:33
# 16    16902 days 18:08:26
# 17    16905 days 09:00:37
# 18    16979 days 10:17:10
# 19    16957 days 13:51:34
# 20    16859 days 02:31:08
# 21    16892 days 12:23:17
# 22    16900 days 03:41:30
# 23    16977 days 10:55:49
# 24    16955 days 08:56:30
# 25    16845 days 13:49:19
# 26    16858 days 22:14:51
# 27    16972 days 23:18:50
# 28    16965 days 22:12:19
# 29    16883 days 14:49:30
#               ...
# 471   16836 days 18:11:25
# 472   16913 days 17:29:22
# 473   16906 days 08:34:48
# 474   16908 days 01:52:55
# 475   16914 days 12:26:03
# ...

# %%
date1 = pd.Series(pd.date_range('2012-1-1 12:00:00', periods=7, freq='D'))
#date2 = pd.Series(pd.date_range('2013-3-11 21:45:00', periods=7, freq='W'))

date2 = pd.Series(pd.date_range('2012-1-2 12:00:00', periods=7, freq='D'))

df3 = pd.DataFrame(dict(Start_date = date1, End_date = date2))
print(df3)
# Out:
#            Start_date            End_date
# 0 2012-01-01 12:00:00 2012-01-02 12:00:00
# 1 2012-01-02 12:00:00 2012-01-03 12:00:00
# 2 2012-01-03 12:00:00 2012-01-04 12:00:00
# 3 2012-01-04 12:00:00 2012-01-05 12:00:00
# 4 2012-01-05 12:00:00 2012-01-06 12:00:00
# 5 2012-01-06 12:00:00 2012-01-07 12:00:00
# 6 2012-01-07 12:00:00 2012-01-08 12:00:00

# %%
import numpy as np

# %%
df3['diff_days'] = df3['End_date'] - df3['Start_date']
print(df3)
# Out:
#            Start_date            End_date         diff_days
# 0 2012-01-31 12:00:00 2013-03-17 21:45:00 411 days 09:45:00
# 1 2012-02-29 12:00:00 2013-03-24 21:45:00 389 days 09:45:00
# 2 2012-03-31 12:00:00 2013-03-31 21:45:00 365 days 09:45:00
# 3 2012-04-30 12:00:00 2013-04-07 21:45:00 342 days 09:45:00
# 4 2012-05-31 12:00:00 2013-04-14 21:45:00 318 days 09:45:00
# 5 2012-06-30 12:00:00 2013-04-21 21:45:00 295 days 09:45:00
# 6 2012-07-31 12:00:00 2013-04-28 21:45:00 271 days 09:45:00

# %%
df3['diff_days'] = df3['End_date'] - df3['Start_date']
df3['diff_days']=df3['diff_days']/np.timedelta64(1,'D')
 
print(df3)
# Out:
#            Start_date            End_date  diff_days
# 0 2012-01-01 12:00:00 2012-01-02 12:00:00        1.0
# 1 2012-01-02 12:00:00 2012-01-03 12:00:00        1.0
# 2 2012-01-03 12:00:00 2012-01-04 12:00:00        1.0
# 3 2012-01-04 12:00:00 2012-01-05 12:00:00        1.0
# 4 2012-01-05 12:00:00 2012-01-06 12:00:00        1.0
# 5 2012-01-06 12:00:00 2012-01-07 12:00:00        1.0
# 6 2012-01-07 12:00:00 2012-01-08 12:00:00        1.0

# %%
df3['diff_weeks'] = df3['End_date'] - df3['Start_date']
df3['diff_weeks']=df3['diff_weeks']/np.timedelta64(1,'W')
 
print(df3)
# Out:
#            Start_date            End_date  diff_days  diff_weeks  diff_minutes
# 0 2012-01-01 12:00:00 2012-01-02 12:00:00        1.0    0.142857        1440.0
# 1 2012-01-02 12:00:00 2012-01-03 12:00:00        1.0    0.142857        1440.0
# 2 2012-01-03 12:00:00 2012-01-04 12:00:00        1.0    0.142857        1440.0
# 3 2012-01-04 12:00:00 2012-01-05 12:00:00        1.0    0.142857        1440.0
# 4 2012-01-05 12:00:00 2012-01-06 12:00:00        1.0    0.142857        1440.0
# 5 2012-01-06 12:00:00 2012-01-07 12:00:00        1.0    0.142857        1440.0
# 6 2012-01-07 12:00:00 2012-01-08 12:00:00        1.0    0.142857        1440.0

# %%
df3['diff_weeks'] = df3['End_date'] - df3['Start_date']
df3['diff_minutes']=df3['diff_weeks']/np.timedelta64(1,'m')
 
print(df3)
# Out:
#            Start_date            End_date  diff_days diff_weeks  diff_minutes  \
# 0 2012-01-01 12:00:00 2012-01-02 12:00:00        1.0     1 days        1440.0
# 1 2012-01-02 12:00:00 2012-01-03 12:00:00        1.0     1 days        1440.0
# 2 2012-01-03 12:00:00 2012-01-04 12:00:00        1.0     1 days        1440.0
# 3 2012-01-04 12:00:00 2012-01-05 12:00:00        1.0     1 days        1440.0
# 4 2012-01-05 12:00:00 2012-01-06 12:00:00        1.0     1 days        1440.0
# 5 2012-01-06 12:00:00 2012-01-07 12:00:00        1.0     1 days        1440.0
# 6 2012-01-07 12:00:00 2012-01-08 12:00:00        1.0     1 days        1440.0
#
#    diff_seconds  diff_nenoseconds
# 0       86400.0      8.640000e+13
# 1       86400.0      8.640000e+13
# 2       86400.0      8.640000e+13
# 3       86400.0      8.640000e+13
# 4       86400.0      8.640000e+13
# 5       86400.0      8.640000e+13
# 6       86400.0      8.640000e+13

# %%
df3['diff_weeks'] = df3['End_date'] - df3['Start_date']
df3['diff_seconds']=df3['diff_weeks']/np.timedelta64(1,'s')
 
print(df3)
# Out:
#            Start_date            End_date  diff_days diff_weeks  diff_minutes  \
# 0 2012-01-01 12:00:00 2012-01-02 12:00:00        1.0     1 days        1440.0
# 1 2012-01-02 12:00:00 2012-01-03 12:00:00        1.0     1 days        1440.0
# 2 2012-01-03 12:00:00 2012-01-04 12:00:00        1.0     1 days        1440.0
# 3 2012-01-04 12:00:00 2012-01-05 12:00:00        1.0     1 days        1440.0
# 4 2012-01-05 12:00:00 2012-01-06 12:00:00        1.0     1 days        1440.0
# 5 2012-01-06 12:00:00 2012-01-07 12:00:00        1.0     1 days        1440.0
# 6 2012-01-07 12:00:00 2012-01-08 12:00:00        1.0     1 days        1440.0
#
#    diff_seconds
# 0       86400.0
# 1       86400.0
# 2       86400.0
# 3       86400.0
# 4       86400.0
# 5       86400.0
# 6       86400.0

# %%
df3['diff_weeks'] = df3['End_date'] - df3['Start_date']
df3['diff_nenoseconds']=df3['diff_weeks']/np.timedelta64(1,'ns')
 
print(df3)
# Out:
#            Start_date            End_date  diff_days diff_weeks  diff_minutes  \
# 0 2012-01-01 12:00:00 2012-01-02 12:00:00        1.0     1 days        1440.0
# 1 2012-01-02 12:00:00 2012-01-03 12:00:00        1.0     1 days        1440.0
# 2 2012-01-03 12:00:00 2012-01-04 12:00:00        1.0     1 days        1440.0
# 3 2012-01-04 12:00:00 2012-01-05 12:00:00        1.0     1 days        1440.0
# 4 2012-01-05 12:00:00 2012-01-06 12:00:00        1.0     1 days        1440.0
# 5 2012-01-06 12:00:00 2012-01-07 12:00:00        1.0     1 days        1440.0
# 6 2012-01-07 12:00:00 2012-01-08 12:00:00        1.0     1 days        1440.0
#
#    diff_seconds  diff_nenoseconds
# 0       86400.0      8.640000e+13
# 1       86400.0      8.640000e+13
# 2       86400.0      8.640000e+13
# 3       86400.0      8.640000e+13
# 4       86400.0      8.640000e+13
# 5       86400.0      8.640000e+13
# 6       86400.0      8.640000e+13

# %% [markdown]
# # PART 2

# %%
import pandas as pd
import numpy as np

# %%
from datetime import datetime

# %%
time_stamp = pd.Timestamp(datetime(2020, 1,1))

# %%
time_stamp
# Out:
# Timestamp('2020-01-01 00:00:00')

# %%
pd.Timestamp(datetime(2020, 1,1)) == time_stamp
# Out:
# True

# %%
time_stamp.year
# Out:
# 2020

# %%
period = pd.Period("2020-01")

# %%
period
# Out:
# Period('2020-01', 'M')

# %%
period.asfreq("D")
# Out:
# Period('2020-01-31', 'D')

# %%
period.to_timestamp().to_period("M")
# Out:
# Period('2020-01', 'M')

# %%
period+2
# Out:
# Period('2020-03', 'M')

# %%
pd.Timestamp("2020-01-31","M")+1
# Out:
# D:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Addition/subtraction of integers and integer-arrays to Timestamp is deprecated, will be removed in a future version.  Instead of adding/subtracting `n`, use `n * self.freq`
#   """Entry point for launching an IPython kernel.
# Timestamp('2020-02-29 00:00:00', freq='M')

# %%
index = pd.date_range(start="2020-1-31", periods=12, freq="M")

# %%
index
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30', '2020-10-31', '2020-11-30', '2020-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
pd.DataFrame({ ('2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
               '2020-05-31', '2020-06-30', '2020-07-31') : index}).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 1 columns):
# (2020-01-31, 2020-02-29, 2020-03-31, 2020-04-30, 2020-05-31, 2020-06-30, 2020-07-31)    12 non-null datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 224.0 bytes

# %%
data = np.random.random(  size=12 )

# %%
df =pd.DataFrame(data, index=index)
df
# Out:
#                    0
# 2020-01-31  0.520231
# 2020-02-29  0.818606
# 2020-03-31  0.751398
# 2020-04-30  0.276181
# 2020-05-31  0.138130
# 2020-06-30  0.495509
# 2020-07-31  0.463325
# 2020-08-31  0.258901
# 2020-09-30  0.091671
# 2020-10-31  0.013161
# 2020-11-30  0.488566
# 2020-12-31  0.811903

# %%
type(df)
# Out:
# NoneType

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12 entries, 2020-01-31 to 2020-12-31
# Freq: M
# Data columns (total 1 columns):
# 0    12 non-null float64
# dtypes: float64(1)
# memory usage: 192.0 bytes

# %%
#parsing string dates and convertng to datetime64. DataTimeIndex freq. Upsampling, DownSampling

#file =s"D:\18-DS\github\K10-GoogleStockPrice\Google_Stock_Price_Train.csv"
google = pd.read_csv("D:\\18-DS\\github\\K10-GoogleStockPrice\\Google_Stock_Price_Train.csv")

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 6 columns):
# Date      1258 non-null object
# Open      1258 non-null float64
# High      1258 non-null float64
# Low       1258 non-null float64
# Close     1258 non-null object
# Volume    1258 non-null object
# dtypes: float64(3), object(3)
# memory usage: 59.1+ KB

# %%
google.Date = pd.to_datetime(google.Date)

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 6 columns):
# Date      1258 non-null datetime64[ns]
# Open      1258 non-null float64
# High      1258 non-null float64
# Low       1258 non-null float64
# Close     1258 non-null object
# Volume    1258 non-null object
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 59.1+ KB

# %%
google.set_index("Date",inplace=True)

# %%
google
# Out:
#               Open    High     Low   Close      Volume
# Date
# 2012-01-03  325.25  332.83  324.97  663.59   7,380,500
# 2012-01-04  331.27  333.87  329.08  666.45   5,749,400
# 2012-01-05  329.83  330.75  326.89  657.21   6,590,300
# 2012-01-06  328.34  328.77  323.68  648.24   5,405,900
# 2012-01-09  322.04  322.29  309.46  620.76  11,688,800
# ...            ...     ...     ...     ...         ...
# 2016-12-23  790.90  792.74  787.28  789.91     623,400
# 2016-12-27  790.68  797.86  787.66  791.55     789,100
# 2016-12-28  793.70  794.23  783.20  785.05   1,153,800
# 2016-12-29  783.33  785.93  778.92  782.79     744,300
# 2016-12-30  782.75  782.78  770.41  771.82   1,770,000
#
# [1258 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
google.Open.plot(title="Opening Stock Price")
plt.show()

# %%
google["2015"]
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2015-01-02  527.56  529.82  522.67  523.37  1,447,500
# 2015-01-05  521.83  522.89  511.66  512.46  2,059,800
# 2015-01-06  513.59  514.76  499.68  500.59  2,899,900
# 2015-01-07  505.61  505.86  498.28  499.73  2,065,000
# 2015-01-08  496.63  502.10  489.66   501.3  3,353,500
# ...            ...     ...     ...     ...        ...
# 2015-12-24  749.55  751.35  746.62   748.4    527,200
# 2015-12-28  752.92  762.99  749.52  762.51  1,515,300
# 2015-12-29  766.69  779.98  766.43   776.6  1,765,000
# 2015-12-30  776.60  777.60  766.90     771  1,293,300
# 2015-12-31  769.50  769.50  758.34  758.88  1,489,600
#
# [252 rows x 5 columns]

# %%
google["2015-01": "2015-03"]
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2015-01-02  527.56  529.82  522.67  523.37  1,447,500
# 2015-01-05  521.83  522.89  511.66  512.46  2,059,800
# 2015-01-06  513.59  514.76  499.68  500.59  2,899,900
# 2015-01-07  505.61  505.86  498.28  499.73  2,065,000
# 2015-01-08  496.63  502.10  489.66   501.3  3,353,500
# ...            ...     ...     ...     ...        ...
# 2015-03-25  568.94  570.69  557.21  557.26  2,152,200
# 2015-03-26  556.06  557.37  549.14  553.65  1,572,600
# 2015-03-27  551.49  553.76  546.63  546.84  1,897,400
# 2015-03-30  550.11  551.95  546.67  550.52  1,287,500
# 2015-03-31  548.49  553.19  545.22   546.5  1,588,000
#
# [61 rows x 5 columns]

# %%
google.loc["2016-01","Open"]
# Out:
# Date
# 2016-01-04    743.00
# 2016-01-05    746.45
# 2016-01-06    730.00
# 2016-01-07    730.31
# 2016-01-08    731.45
# 2016-01-11    716.61
# 2016-01-12    721.68
# 2016-01-13    730.85
# 2016-01-14    705.38
# 2016-01-15    692.29
# 2016-01-19    703.30
# 2016-01-20    688.61
# 2016-01-21    702.18
# 2016-01-22    723.60
# 2016-01-25    723.58
# 2016-01-26    713.85
# 2016-01-27    713.67
# 2016-01-28    722.22
# 2016-01-29    731.53
# Name: Open, dtype: float64

# %%
google.asfreq("Y")
# Out:
#               Open    High     Low     Close     Volume
# Date
# 2012-12-31  348.69  353.96  346.70    705.44  4,009,600
# 2013-12-31  554.04  558.41  551.06  1,117.64  2,725,900
# 2014-12-31  529.80  531.14  524.36    524.96  1,368,200
# 2015-12-31  769.50  769.50  758.34    758.88  1,489,600

# %%
google.asfreq("M")
# Out:
#               Open    High     Low     Close      Volume
# Date
# 2012-01-31  290.41  290.91  286.50    578.52   4,300,700
# 2012-02-29  308.14  311.63  306.60    616.56   6,297,200
# 2012-03-31     NaN     NaN     NaN       NaN         NaN
# 2012-04-30  305.35  306.89  299.18    603.19   4,832,600
# 2012-05-31  293.26  293.90  288.42    579.27   5,958,800
# 2012-06-30     NaN     NaN     NaN       NaN         NaN
# 2012-07-31  312.96  317.06  312.94    631.24   3,745,100
# 2012-08-31  340.72  343.00  338.75    683.21   4,270,000
# 2012-09-30     NaN     NaN     NaN       NaN         NaN
# 2012-10-31  338.66  339.23  336.24    678.44   3,085,400
# 2012-11-30  344.36  348.30  341.56    696.46   6,350,800
# 2012-12-31  348.69  353.96  346.70    705.44   4,009,600
# 2013-01-31  373.85  377.40  373.72    753.62   3,280,500
# 2013-02-28  399.05  401.99  399.02    799.01   4,548,500
# 2013-03-31     NaN     NaN     NaN       NaN         NaN
# ...

# %%
google.asfreq("W")
# Out:
#             Open  High  Low Close Volume
# Date
# 2012-01-08   NaN   NaN  NaN   NaN    NaN
# 2012-01-15   NaN   NaN  NaN   NaN    NaN
# 2012-01-22   NaN   NaN  NaN   NaN    NaN
# 2012-01-29   NaN   NaN  NaN   NaN    NaN
# 2012-02-05   NaN   NaN  NaN   NaN    NaN
# ...          ...   ...  ...   ...    ...
# 2016-11-27   NaN   NaN  NaN   NaN    NaN
# 2016-12-04   NaN   NaN  NaN   NaN    NaN
# 2016-12-11   NaN   NaN  NaN   NaN    NaN
# 2016-12-18   NaN   NaN  NaN   NaN    NaN
# 2016-12-25   NaN   NaN  NaN   NaN    NaN
#
# [260 rows x 5 columns]

# %%
google.asfreq("B")
# Out:
#               Open    High     Low   Close      Volume
# Date
# 2012-01-03  325.25  332.83  324.97  663.59   7,380,500
# 2012-01-04  331.27  333.87  329.08  666.45   5,749,400
# 2012-01-05  329.83  330.75  326.89  657.21   6,590,300
# 2012-01-06  328.34  328.77  323.68  648.24   5,405,900
# 2012-01-09  322.04  322.29  309.46  620.76  11,688,800
# ...            ...     ...     ...     ...         ...
# 2016-12-26     NaN     NaN     NaN     NaN         NaN
# 2016-12-27  790.68  797.86  787.66  791.55     789,100
# 2016-12-28  793.70  794.23  783.20  785.05   1,153,800
# 2016-12-29  783.33  785.93  778.92  782.79     744,300
# 2016-12-30  782.75  782.78  770.41  771.82   1,770,000
#
# [1304 rows x 5 columns]

# %%
google.asfreq("D")
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2012-01-03  325.25  332.83  324.97  663.59  7,380,500
# 2012-01-04  331.27  333.87  329.08  666.45  5,749,400
# 2012-01-05  329.83  330.75  326.89  657.21  6,590,300
# 2012-01-06  328.34  328.77  323.68  648.24  5,405,900
# 2012-01-07     NaN     NaN     NaN     NaN        NaN
# ...            ...     ...     ...     ...        ...
# 2016-12-26     NaN     NaN     NaN     NaN        NaN
# 2016-12-27  790.68  797.86  787.66  791.55    789,100
# 2016-12-28  793.70  794.23  783.20  785.05  1,153,800
# 2016-12-29  783.33  785.93  778.92  782.79    744,300
# 2016-12-30  782.75  782.78  770.41  771.82  1,770,000
#
# [1824 rows x 5 columns]

# %%
google[ google.Open.isnull()]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume]
# Index: []

# %%
google.asfreq("D")
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2012-01-03  325.25  332.83  324.97  663.59  7,380,500
# 2012-01-04  331.27  333.87  329.08  666.45  5,749,400
# 2012-01-05  329.83  330.75  326.89  657.21  6,590,300
# 2012-01-06  328.34  328.77  323.68  648.24  5,405,900
# 2012-01-07     NaN     NaN     NaN     NaN        NaN
# ...            ...     ...     ...     ...        ...
# 2016-12-26     NaN     NaN     NaN     NaN        NaN
# 2016-12-27  790.68  797.86  787.66  791.55    789,100
# 2016-12-28  793.70  794.23  783.20  785.05  1,153,800
# 2016-12-29  783.33  785.93  778.92  782.79    744,300
# 2016-12-30  782.75  782.78  770.41  771.82  1,770,000
#
# [1824 rows x 5 columns]

# %%
data = pd.read_csv("D:\\18-DS\\github\\K10-GoogleStockPrice\\Google_Stock_Price_Train.csv")

# Inspect data
print(data)

# Convert the date column to datetime64
data.Date = pd.to_datetime(data.Date)


# Set date column as index

data.set_index("Date", inplace=True)
# Inspect data 
print(data)

# Plot data
#plt.subplots=True
data.Open.plot()
plt.show()
# Out:
#             Date    Open    High     Low   Close      Volume
# 0       1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1       1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2       1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3       1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4       1/9/2012  322.04  322.29  309.46  620.76  11,688,800
# ...          ...     ...     ...     ...     ...         ...
# 1253  12/23/2016  790.90  792.74  787.28  789.91     623,400
# 1254  12/27/2016  790.68  797.86  787.66  791.55     789,100
# 1255  12/28/2016  793.70  794.23  783.20  785.05   1,153,800
# 1256  12/29/2016  783.33  785.93  778.92  782.79     744,300
# 1257  12/30/2016  782.75  782.78  770.41  771.82   1,770,000
#
# [1258 rows x 6 columns]
#               Open    High     Low   Close      Volume
# Date
# 2012-01-03  325.25  332.83  324.97  663.59   7,380,500
# 2012-01-04  331.27  333.87  329.08  666.45   5,749,400
# ...

# %%
yahoo = pd.read_csv("D:\\18-DS\\github\\K10-GoogleStockPrice\\Google_Stock_Price_Train.csv")
yahoo.Date = pd.to_datetime(yahoo.Date)
print (yahoo.head())
yahoo.set_index("Date", inplace=True)
yahoo.asfreq("D")
# Out:
#         Date    Open    High     Low   Close      Volume
# 0 2012-01-03  325.25  332.83  324.97  663.59   7,380,500
# 1 2012-01-04  331.27  333.87  329.08  666.45   5,749,400
# 2 2012-01-05  329.83  330.75  326.89  657.21   6,590,300
# 3 2012-01-06  328.34  328.77  323.68  648.24   5,405,900
# 4 2012-01-09  322.04  322.29  309.46  620.76  11,688,800
#               Open    High     Low   Close     Volume
# Date
# 2012-01-03  325.25  332.83  324.97  663.59  7,380,500
# 2012-01-04  331.27  333.87  329.08  666.45  5,749,400
# 2012-01-05  329.83  330.75  326.89  657.21  6,590,300
# 2012-01-06  328.34  328.77  323.68  648.24  5,405,900
# 2012-01-07     NaN     NaN     NaN     NaN        NaN
# ...            ...     ...     ...     ...        ...
# 2016-12-26     NaN     NaN     NaN     NaN        NaN
# 2016-12-27  790.68  797.86  787.66  791.55    789,100
# 2016-12-28  793.70  794.23  783.20  785.05  1,153,800
# 2016-12-29  783.33  785.93  778.92  782.79    744,300
# ...

# %%
yahoo.loc["2016-01","Open"]
# Out:
# Date
# 2016-01-04    743.00
# 2016-01-05    746.45
# 2016-01-06    730.00
# 2016-01-07    730.31
# 2016-01-08    731.45
# 2016-01-11    716.61
# 2016-01-12    721.68
# 2016-01-13    730.85
# 2016-01-14    705.38
# 2016-01-15    692.29
# 2016-01-19    703.30
# 2016-01-20    688.61
# 2016-01-21    702.18
# 2016-01-22    723.60
# 2016-01-25    723.58
# 2016-01-26    713.85
# 2016-01-27    713.67
# 2016-01-28    722.22
# 2016-01-29    731.53
# Name: Open, dtype: float64

# %%
yahoo.loc[ "2015" ]
# Out:
#               Open    High     Low   Close     Volume
# Date
# 2015-01-02  527.56  529.82  522.67  523.37  1,447,500
# 2015-01-05  521.83  522.89  511.66  512.46  2,059,800
# 2015-01-06  513.59  514.76  499.68  500.59  2,899,900
# 2015-01-07  505.61  505.86  498.28  499.73  2,065,000
# 2015-01-08  496.63  502.10  489.66   501.3  3,353,500
# ...            ...     ...     ...     ...        ...
# 2015-12-24  749.55  751.35  746.62   748.4    527,200
# 2015-12-28  752.92  762.99  749.52  762.51  1,515,300
# 2015-12-29  766.69  779.98  766.43   776.6  1,765,000
# 2015-12-30  776.60  777.60  766.90     771  1,293,300
# 2015-12-31  769.50  769.50  758.34  758.88  1,489,600
#
# [252 rows x 5 columns]

# %%
yahoo.asfreq

# %%
yahoo.loc[2013,"Open"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-169-7f79d4e0998e> in <module>
# ----> 1 yahoo.loc[2013,"Open"]
#
# D:\Users\admin\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# D:\Users\admin\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     803     def _getitem_tuple(self, tup):
#     804         try:
# --> 805             return self._getitem_lowerdim(tup)
#     806         except IndexingError:
#     807             pass
#
# D:\Users\admin\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
# ...

# %%
price_per_year.rename(columns "2015")
# Out:
# 0    527.56
# 1    521.83
# 2    513.59
# 3    505.61
# 4    496.63
# Name: 2015, dtype: float64

# %%
# Out:
# <function pdb.set_trace(*, header=None)>

# %%
# Create dataframe prices here
import pdb; pdb.set_trace
yahoo = pd.read_csv("D:\\18-DS\\github\\K10-GoogleStockPrice\\Google_Stock_Price_Train.csv")

yahoo.Date = pd.to_datetime(yahoo.Date)
yahoo.set_index("Date",inplace=True)
yahoo.asfreq("D")
prices = pd.DataFrame()

print (yahoo.head(5))
# Select data for each year and concatenate with prices here 
for year in ["2013", "2014", "2015"]:
    price_per_year = yahoo.loc[year,"Open"].reset_index(drop=True)
  
    price_per_year.rename(columns={year: price_per_year}, inplace=True)
    print (price_per_year)
    prices = pd.concat([prices, price_per_year], axis=1)

# Plot prices
# Out:
#               Open    High     Low   Close      Volume
# Date
# 2012-01-03  325.25  332.83  324.97  663.59   7,380,500
# 2012-01-04  331.27  333.87  329.08  666.45   5,749,400
# 2012-01-05  329.83  330.75  326.89  657.21   6,590,300
# 2012-01-06  328.34  328.77  323.68  648.24   5,405,900
# 2012-01-09  322.04  322.29  309.46  620.76  11,688,800
# 0      358.37
# 1      361.11
# 2      363.31
# 3      366.35
# 4      366.40
#         ...
# 247    555.40
# 248    554.92
# 249    557.91
# 250    558.08
# 251    554.04
# Length: 252, dtype: float64
# 0      555.65
# 1      555.42
# 2      554.43
# 3      560.40
# 4      570.86
#         ...
# 247    529.06
# 248    527.32
# 249    530.73
# 250    526.64
# 251    529.80
# Length: 252, dtype: float64
# 0      527.56
# 1      521.83
# 2      513.59
# 3      505.61
# 4      496.63
#         ...
# 247    749.55
# 248    752.92
# 249    766.69
# 250    776.60
# 251    769.50
# Length: 252, dtype: float64

# %%
prices
# Out:
#           0       0       0
# 0    358.37  555.65  527.56
# 1    361.11  555.42  521.83
# 2    363.31  554.43  513.59
# 3    366.35  560.40  505.61
# 4    366.40  570.86  496.63
# ..      ...     ...     ...
# 247  555.40  529.06  749.55
# 248  554.92  527.32  752.92
# 249  557.91  530.73  766.69
# 250  558.08  526.64  776.60
# 251  554.04  529.80  769.50
#
# [252 rows x 3 columns]

# %%
type(prices)
# Out:
# pandas.core.frame.DataFrame
