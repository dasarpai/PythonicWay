# %%
import re

# %%
re.search(r'c\d\dkie', 'c00kie').group()
# Out:
# 'c00kie'

# %%
re.search(r'c\d\dkie', 'c00kie').group()
# Out:
# 'c00kie'

# %%
t1= 'Trasport' 
t2= '*'
re.search(t1 + '\*', t1+t2).group()
# Out:
# 'Trasport*'

# %%
re.search(r'cake*$', 'Eat cake*').group()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-d2224cadc85c> in <module>
# ----> 1 re.search(r'cake*$', 'Eat cake*').group()
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
re.search(r'Number: [$]', 'Number: *').group()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-01ca4cdd57cd> in <module>
# ----> 1 re.search(r'Number: [$]', 'Number: *').group()
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
re.search(r'something\*', 'Backstail*').group()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-516139b4465e> in <module>
# ----> 1 re.search(r'something\*', 'Backstail*').group()
#
# AttributeError: 'NoneType' object has no attribute 'group'
