# %%
# !pip show numpy
# Out:
# Name: numpy
# Version: 1.17.4
# Summary: NumPy is the fundamental package for array computing with Python.
# Home-page: https://www.numpy.org
# Author: Travis E. Oliphant et al.
# Author-email: None
# License: BSD
# Location: c:\users\admin\appdata\roaming\python\python37\site-packages
# Requires:
# Required-by: opt-einsum, xgboost, torchvision, torch, thinc, tensorflow, tensorboard, tabula-py, tables, stanfordnlp, spacy, seaborn, scipy, scikit-learn, PyWavelets, pytorch-pretrained-bert, pytest-doctestplus, pytest-arraydiff, patsy, pandas, opencv-python, odo, numexpr, numba, mkl-random, mkl-fft, matplotlib, lmfit, lightgbm, Keras, Keras-Preprocessing, Keras-Applications, inltk, indic-nlp-library, imbalanced-learn, h5py, fastai, datashape, Bottleneck, bokeh, blis, bkcharts, astropy

# %%
# !pip show sklearn
# Out:
# Name: sklearn
# Version: 0.0
# Summary: A set of python modules for machine learning and data mining
# Home-page: https://pypi.python.org/pypi/scikit-learn/
# Author: UNKNOWN
# Author-email: UNKNOWN
# License: None
# Location: d:\users\admin\anaconda3\lib\site-packages
# Requires: scikit-learn
# Required-by:

# %%
# !pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 0.22
# Summary: A set of python modules for machine learning and data mining
# Home-page: http://scikit-learn.org
# Author: None
# Author-email: None
# License: new BSD
# Location: d:\users\admin\anaconda3\lib\site-packages
# Requires: scipy, joblib, numpy
# Required-by: sklearn, lightgbm, imbalanced-learn

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- ------------
# -cikit-learn                       0.22
# absl-py                            0.8.1
# aiohttp                            3.6.2
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.6
# anaconda-project                   0.8.2
# asn1crypto                         0.24.0
# asteval                            0.9.16
# astor                              0.8.0
# astroid                            2.1.0
# astropy                            3.1
# async-timeout                      3.0.1
# atomicwrites                       1.2.1
# attrs                              18.2.0
# Babel                              2.6.0
# backcall                           0.1.0
# backports.os                       0.1.1
# backports.shutil-get-terminal-size 1.0.0
# beautifulsoup4                     4.6.3
# bitarray                           0.8.3
# ...
